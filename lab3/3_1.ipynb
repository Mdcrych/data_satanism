# %%
import pandas as pd

generation_df = pd.read_csv('data/global-electricity-generation.csv')
generation_df.set_index('Country', inplace=True)

consumption_df = pd.read_csv('data/global-electricity-consumption.csv')
consumption_df.set_index('Country', inplace=True)

for col in generation_df.columns:
    generation_df[col] = pd.to_numeric(generation_df[col], errors='coerce')
for col in consumption_df.columns:
    consumption_df[col] = pd.to_numeric(consumption_df[col], errors='coerce')


print("Производство электроэнергии:")
display(generation_df.head())

print("\nПотребление электроэнергии:")
display(consumption_df.head())
# Out:
# Производство электроэнергии:
#                 1992    1993    1994    1995     1996     1997     1998  \
# Country
# Algeria       17.199  18.267  18.703  18.090  19.1240  19.7390  21.4480
# Angola         1.283   1.332   1.342   1.347   1.3770   1.3310   1.5200
# Benin          0.023   0.024   0.048   0.029   0.0487   0.0517   0.0597
# Botswana       1.088   1.027   1.044   1.047   0.7590   0.8700   1.0260
# Burkina Faso   0.190   0.205   0.206   0.232   0.2630   0.2820   0.3120
#
#                  1999      2000      2001  ...      2012      2013      2014  \
# Country                                    ...
# Algeria       23.2820  23.88952  25.03064  ...  53.98450  56.31340  60.39972
# Angola         1.3000   1.40402   1.59074  ...   6.03408   7.97606   9.21666
# Benin          0.0677   0.07908   0.06216  ...   0.04612   0.08848   0.22666
# Botswana       1.0430   0.89018   0.94940  ...   0.33000   0.86868   2.17628
# Burkina Faso   0.3480   0.31800   0.32700  ...   0.86834   0.98268   1.11808
#
#                   2015       2016      2017      2018      2019       2020  \
# Country
# Algeria       64.68244  66.755040  71.49546  72.10903  76.68500  72.735913
# Angola         9.30914  10.203511  10.67604  12.83194  15.40000  16.600000
# Benin          0.31056   0.260040   0.31150   0.19028   0.20170   0.226080
# Botswana       2.79104   2.529840   2.84380   2.97076   3.04690   2.051440
# Burkina Faso   1.43986   1.550900   1.64602   1.64640   1.72552   1.647133
#
#                    2021
# Country
# Algeria       77.530727
# Angola        16.429392
# Benin          0.241097
# Botswana       2.182348
# Burkina Faso   1.761210
#
# [5 rows x 30 columns]
# Потребление электроэнергии:
#                   1992      1993      1994      1995      1996      1997  \
# Country
# Algeria       14.03500  14.03900  14.36500  14.47400  15.17200  15.36500
# Angola         1.01300   1.06200   1.07100   1.07400   1.08500   1.21600
# Benin          0.22900   0.22100   0.25200   0.24200   0.27870   0.27970
# Botswana       1.09184   1.11411   1.28092   1.31371   1.39087   1.55710
# Burkina Faso   0.17670   0.19065   0.19158   0.21576   0.24459   0.26226
#
#                   1998      1999      2000      2001  ...      2012      2013  \
# Country                                               ...
# Algeria       16.90500  18.49200  19.71552  20.64764  ...  42.86750  45.20140
# Angola         1.32800   1.10600   1.19302   1.35274  ...   5.33508   7.05006
# Benin          0.27070   0.31470   0.39008   0.39516  ...   0.93312   0.93648
# Botswana       1.57100   1.74900   1.71218   2.02240  ...   3.20900   3.34768
# Burkina Faso   0.29016   0.32364   0.26900   0.32970  ...   1.24784   1.35648
#
#                    2014      2015       2016       2017       2018       2019  \
# Country
# Algeria       49.205720  53.45544  55.823040  60.283460  62.114030  66.646000
# Angola         8.148660   8.23114   9.036511   9.468667  11.384079  13.658591
# Benin          0.933660   1.08156   1.061040   1.125821   1.187964   0.929700
# Botswana       3.605280   3.73004   3.615840   3.552800   3.651212   4.162138
# Burkina Faso   1.431962   1.69966   1.997400   2.067920   2.264800   2.651386
#
#                    2020       2021
# Country
# Algeria       63.694903  68.663379
# Angola        14.754764  14.560491
# Benin          0.524080   0.523383
# Botswana       3.222130   3.353038
# Burkina Faso   2.467133   2.642688
#
# [5 rows x 30 columns]

# %%
total_consumption_per_year = consumption_df.sum(axis=0)

print("Суммарное потребление электроэнергии по годам (млрд. кВт*ч):")
print(total_consumption_per_year)
# Out:
# Суммарное потребление электроэнергии по годам (млрд. кВт*ч):
# 1992    10569.016201
# 1993    10854.562919
# 1994    11104.653834
# 1995    11476.479041
# 1996    11805.865473
# 1997    12122.033114
# 1998    12419.808873
# 1999    12685.754131
# 2000    13230.249502
# 2001    13486.489704
# 2002    13938.778793
# 2003    14455.562329
# 2004    15128.097979
# 2005    15725.982376
# 2006    16438.213771
# 2007    17205.119808
# 2008    17477.471007
# 2009    17435.687358
# 2010    18748.160724
# 2011    19438.823496
# 2012    19918.254954
# 2013    20573.096414
# 2014    20981.239762
# 2015    21400.017770
# 2016    22022.686879
# 2017    22716.206102
# 2018    23530.920048
# 2019    23915.656498
# 2020    23959.680109
# 2021    25336.707010
# dtype: float64

# %%
max_generation_single_year = generation_df.max(numeric_only=True).max()

print(f"Максимальное количество электроэнергии, произведенное одной страной за один год: {max_generation_single_year:.2f} млрд. кВт*ч")
# Out:
# Максимальное количество электроэнергии, произведенное одной страной за один год: 8151.52 млрд. кВт*ч

# %%
last_5_years_generation = generation_df.loc[:, '2017':'2021']


average_generation_last_5_years = last_5_years_generation.mean(axis=1)

countries_producing_over_500 = average_generation_last_5_years[average_generation_last_5_years > 500].index.tolist()

print("Страны, производящие в среднем более 500 млрд. кВт*ч за последние 5 лет:")
print(countries_producing_over_500)
# Out:
# Страны, производящие в среднем более 500 млрд. кВт*ч за последние 5 лет:
# ['        Russia', '        France', '        Germany', '        China', '        India', '        Japan', '        South Korea', '        Canada', '        United States', '        Brazil']

# %%
last_5_years_consumption = consumption_df.loc[:, '2017':'2021']


average_consumption_last_5_years = last_5_years_consumption.mean(axis=1)

quantile_90 = average_consumption_last_5_years.quantile(0.9)

top_10_percent_consumers = average_consumption_last_5_years[average_consumption_last_5_years >= quantile_90].index.tolist()

print(f"Порог для топ 10% потребителей: {quantile_90:.2f} млрд. кВт*ч")
print("10% стран, потребляющих больше всего электроэнергии в среднем за последние 5 лет:")
print(top_10_percent_consumers)
# Out:
# Порог для топ 10% потребителей: 198.31 млрд. кВт*ч
# 10% стран, потребляющих больше всего электроэнергии в среднем за последние 5 лет:
# ['        South Africa', '        Russia', '        France', '        Germany', '        Italy', '        Spain', '        Turkiye', '        United Kingdom', '        Australia', '        China', '        India', '        Indonesia', '        Japan', '        South Korea', '        Taiwan', '        Vietnam', '        Iran', '        Saudi Arabia', '        Canada', '        Mexico', '        United States', '        Brazil']

# %%
growth_ratio = generation_df['2021'] / generation_df['1992']


countries_with_10x_growth = growth_ratio[growth_ratio > 10].index.tolist()

print("Страны, увеличившие производство более чем в 10 раз с 1992 по 2021 год:")
print(countries_with_10x_growth)
# Out:
# Страны, увеличившие производство более чем в 10 раз с 1992 по 2021 год:
# ['        Angola', '        Benin', '        Equatorial Guinea', '        Ethiopia', '        Lesotho', '        Mali', '        Mauritania', '        Mozambique', '        Namibia', '        Sudan', '        Cambodia', '        China', '        Laos', '        Maldives', '        Vietnam', '        Turks and Caicos Islands']

# %%
total_consumption = consumption_df.sum(axis=1)


total_generation = generation_df.sum(axis=1)


condition1 = total_consumption > 100


condition2 = total_generation < total_consumption


countries_deficit = total_consumption[condition1 & condition2].index.tolist()

print("Страны с общим потреблением > 100 млрд. кВт*ч и дефицитом производства:")
print(countries_deficit)
# Out:
# Страны с общим потреблением > 100 млрд. кВт*ч и дефицитом производства:
# ['        Zimbabwe', '        Belarus', '        Moldova', '        Belgium', '        Croatia', '        Finland', '        Hungary', '        Italy', '        Latvia', '        Luxembourg', '        Netherlands', '        North Macedonia', '        Hong Kong']

# %%
country_max_consumption_2020 = consumption_df['2020'].idxmax()


max_consumption_value_2020 = consumption_df['2020'].max()

print(f"Страна, потратившая наибольшее количество электроэнергии в 2020 году: {country_max_consumption_2020} ({max_consumption_value_2020:.2f} млрд. кВт*ч)")
# Out:
# Страна, потратившая наибольшее количество электроэнергии в 2020 году:         China (7115.08 млрд. кВт*ч)

# %%
first_5_years = generation_df.iloc[:, :5]

average_generation_first_5_years = first_5_years.mean(axis=1)

quantile_10 = average_generation_first_5_years.quantile(0.1)

bottom_10_percent_countries = average_generation_first_5_years[average_generation_first_5_years <= quantile_10].index.tolist()

print(f"Порог для 10% стран с наименьшей производительностью: {quantile_10:.4f} млрд. кВт*ч")
print(f"\n10% стран с наименьшей производительностью за первые 5 лет (1992-1996):")
for country in bottom_10_percent_countries:
    print(f"  - {country.strip()}")
# Out:
# Порог для 10% стран с наименьшей производительностью: 0.0446 млрд. кВт*ч
#
# 10% стран с наименьшей производительностью за первые 5 лет (1992-1996):
#   - Benin
#   - Comoros
#   - Equatorial Guinea
#   - Lesotho
#   - Saint Helena
#   - Sao Tome and Principe
#   - Cook Islands
#   - Kiribati
#   - Maldives
#   - Nauru
#   - Niue
#   - Solomon Islands
#   - Tonga
#   - Vanuatu
#   - Wake Island
#   - Saint Pierre and Miquelon
#   - Antarctica
#   - British Virgin Islands
#   - Dominica
#   - Falkland Islands
#   - Montserrat
#   - Turks and Caicos Islands
